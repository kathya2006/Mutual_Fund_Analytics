# %%
import os

for f in os.listdir("OtherData"):
    print(f)
# Out:
# .ipynb_checkpoints
# Readme.txt

# %%
import os

csv_files = [f for f in os.listdir("DailyNAV") if f.endswith(".csv")]

print("Number of CSV files:", len(csv_files))

for f in csv_files[:10]:
    print(f)
# Out:
# Number of CSV files: 6856
# data_2006_04_01.csv
# data_2006_04_02.csv
# data_2006_04_03.csv
# data_2006_04_04.csv
# data_2006_04_05.csv
# data_2006_04_06.csv
# data_2006_04_07.csv
# data_2006_04_08.csv
# data_2006_04_09.csv
# data_2006_04_10.csv

# %%
import pandas as pd

df = pd.read_csv("DailyNAV/data_2006_04_05.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns)

print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Shape: (1915, 8)
#
# Columns:
# Index(['Scheme Code', 'Scheme Name', 'ISIN Div Payout/ISIN Growth',
#        'ISIN Div Reinvestment', 'Net Asset Value', 'Repurchase Price',
#        'Sale Price', 'Date'],
#       dtype='str')
#
# First 5 Rows:
#    Scheme Code                                        Scheme Name  \
# 0       102652  ABN AMRO  Monthly Income Plan-Regular Plan-Gro...
# 1       102653  ABN AMRO  Monthly Income Plan-Regular Plan-Mon...
# 2       102654  ABN AMRO  Monthly Income Plan-Regular Plan-Qua...
# 3       102645  ABN AMRO  Short Term Income Fund-Institutional...
# 4       102644  ABN AMRO  Short Term Income Fund-Institutional...
#
#   ISIN Div Payout/ISIN Growth ISIN Div Reinvestment Net Asset Value  \
# 0                         NaN                   NaN         11.7663
# 1                         NaN                   NaN         10.5249
# 2                         NaN                   NaN         10.4692
# ...

# %%
import pandas as pd

df = pd.read_csv("DailyNAV/data_2006_04_05.csv")

print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# Scheme Code                       0
# Scheme Name                       0
# ISIN Div Payout/ISIN Growth     893
# ISIN Div Reinvestment          1352
# Net Asset Value                  21
# Repurchase Price                 20
# Sale Price                       28
# Date                              0
# dtype: int64
#
# Duplicate Rows:
# 0

# %%
import pandas as pd
import os

files = [f for f in os.listdir("DailyNAV") if f.endswith(".csv")][:5]

for file in files:
    df = pd.read_csv(os.path.join("DailyNAV", file))

    print("\n" + "="*50)
    print(file)

    print("Shape:", df.shape)

    print("Missing Values:")
    print(df.isnull().sum().sum())

    print("Duplicates:")
    print(df.duplicated().sum())
# Out:
# ...
# data_2006_04_01.csv
# Shape: (82, 8)
# Missing Values:
# 86
# Duplicates:
# 0
#
# ...
# data_2006_04_02.csv
# Shape: (404, 8)
# Missing Values:
# 466
# Duplicates:
# 0
#
# ...
# data_2006_04_03.csv
# Shape: (1794, 8)
# Missing Values:
# 2041
# Duplicates:
# 0
#
# ...
# data_2006_04_04.csv
# Shape: (1799, 8)
# Missing Values:
# 2051
# Duplicates:
# 0
#
# ...
# data_2006_04_05.csv
# Shape: (1915, 8)
# Missing Values:
# 2314
# Duplicates:
# 0

# %%
import pandas as pd
import os

all_data = []

files = [f for f in os.listdir("DailyNAV") if f.endswith(".csv")]

for file in files[:50]:   # start with first 50 files
    df = pd.read_csv(os.path.join("DailyNAV", file))
    all_data.append(df)

combined_df = pd.concat(all_data, ignore_index=True)

print(combined_df.shape)
# Out:
# (60750, 8)

# %%
import requests

url = "https://api.mfapi.in/mf/125497"

response = requests.get(url)

print(response.status_code)

data = response.json()

print(data.keys())
# Out:
# 200
# dict_keys(['meta', 'data', 'status'])

# %%
import pandas as pd

nav_df = pd.DataFrame(data['data'])

nav_df.to_csv(
    "DailyNAV/HDFC_Top100_NAV.csv",
    index=False
)

print("File Saved Successfully")
# Out:
# File Saved Successfully

# %%
import requests
import pandas as pd

funds = {
    "SBI_Bluechip": 119551,
    "ICICI_Bluechip": 120503,
    "Nippon_LargeCap": 118632,
    "Axis_Bluechip": 119092,
    "Kotak_Bluechip": 120841
}

for name, code in funds.items():

    url = f"https://api.mfapi.in/mf/{code}"

    response = requests.get(url)

    data = response.json()

    df = pd.DataFrame(data['data'])

    df.to_csv(
        f"DailyNAV/{name}.csv",
        index=False
    )

    print(name, "saved")
# Out:
# SBI_Bluechip saved
# ICICI_Bluechip saved
# Nippon_LargeCap saved
# Axis_Bluechip saved
# Kotak_Bluechip saved

# %%
df = pd.read_csv("DailyNAV/data_2006_04_05.csv")

print("Missing Values:")
print(df.isnull().sum())

print("\nDuplicates:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# Scheme Code                       0
# Scheme Name                       0
# ISIN Div Payout/ISIN Growth     893
# ISIN Div Reinvestment          1352
# Net Asset Value                  21
# Repurchase Price                 20
# Sale Price                       28
# Date                              0
# dtype: int64
#
# Duplicates:
# 0
